# %%
import pandas as pd
df_corpus = pd.read_csv("/Users/andrea/Desktop/US_youtube_trending_data.csv")

# %%
df_corpus.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
import texthero as hero

# %%
df_corpus['clean_title'] = hero.clean(df_corpus['title'])

# %%
df_corpus['clean_title'].head
# Out:
# <bound method NDFrame.head of 0                                          asked girlfriend
# 1            apex legends stories outlands - " endorsement"
# 2                               left youtube month happened
# 3         xxl freshman class revealed official announcement
# 4            ultimate diy home movie theater labrant family
#                                 ...
# 167785        brutally honest pokemon scarlet violet review
# 167786    pharrell williams travis scott atlanta officia...
# 167787             nate smith wreckage official music video
# 167788                   saweetie say nothin official audio
# 167789                                guess price keep item
# Name: clean_title, Length: 167790, dtype: object>

# %%
import matplotlib.pyplot as plt
NUM_TOP_WORDS = 20
top_20 = hero.visualization.top_words(df_corpus.loc[:, 'clean_title']).head(NUM_TOP_WORDS)
top_20.plot.bar(rot=90, title="Top 20 titles in most popular videos");
plt.show();

# %%
hero.wordcloud(df_corpus.loc[:, 'clean_title'], max_words=100)
